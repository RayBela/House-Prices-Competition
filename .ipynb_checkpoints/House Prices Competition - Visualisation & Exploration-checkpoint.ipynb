# %% [markdown]
# # House Prices Competition : Term Project

# %% [markdown]
# ### Description of the dataset :

# %% [markdown]
# The house prices competition dataset contains information about several houses in Ames, Iowa, with 79 explanatory variables describing (almost) every aspect of residential homes in this area.
#
# A full description will be found here :

# %% [markdown]
# We followed a specific workflow in this competition, we started with a full EDA (exploratory data analysis), then with preprocessing and feature engineering, and we finished with modelling and the use of ensamble learning methods

# %% [markdown]
# ### Importing Libraries:

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn import linear_model
from sklearn.metrics import mean_squared_error
from sklearn.decomposition import PCA
from sklearn.base import TransformerMixin
import sklearn.preprocessing as pp
from sklearn.preprocessing import MinMaxScaler
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Lasso


import matplotlib.pyplot as plt
plt.style.use(style='ggplot')
plt.rcParams['figure.figsize'] = (10, 6)

# %% [markdown]
# Reading train and test files

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %% [markdown]
# ### General Description of The Dataset

# %% [markdown]
# Showing head of the train dataset

# %%
train.head()
train.shape
# Out:
# (1460, 81)

# %% [markdown]
# Showing shape of the train dataset

# %%
print ("Train data shape:", train.shape)
# Out:
# Train data shape: (1460, 81)

# %% [markdown]
# Showing shape of the test dataset

# %%
print ("Train data shape:", test.shape)
# Out:
# Train data shape: (1459, 80)

# %% [markdown]
# Showing data types of the train dataset

# %%
train.get_dtype_counts()
# Out:
# float64     3
# int64      35
# object     43
# dtype: int64

# %% [markdown]
# Showing data types of the test dataset

# %%
test.get_dtype_counts()
# Out:
# float64    11
# int64      26
# object     43
# dtype: int64

# %% [markdown]
# Save "Id" and drop it from the train dataset (we do not need it as a feature)

# %%
train_ID = train['Id']

train.drop("Id", axis = 1, inplace = True)
train.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig    ...     PoolArea PoolQC Fence  \
# 0         Lvl    AllPub    Inside    ...            0    NaN   NaN
# 1         Lvl    AllPub       FR2    ...            0    NaN   NaN
# 2         Lvl    AllPub    Inside    ...            0    NaN   NaN
# 3         Lvl    AllPub    Corner    ...            0    NaN   NaN
# 4         Lvl    AllPub       FR2    ...            0    NaN   NaN
#
#   MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0         NaN       0      2    2008        WD         Normal     208500
# ...

# %% [markdown]
# Save "Id" and drop it from the test dataset (we do not need it as a feature)

# %%
test_ID = test['Id']

test.drop("Id", axis = 1, inplace = True)
test.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          20       RH         80.0    11622   Pave   NaN      Reg
# 1          20       RL         81.0    14267   Pave   NaN      IR1
# 2          60       RL         74.0    13830   Pave   NaN      IR1
# 3          60       RL         78.0     9978   Pave   NaN      IR1
# 4         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig      ...       ScreenPorch PoolArea PoolQC  \
# 0         Lvl    AllPub    Inside      ...               120        0    NaN
# 1         Lvl    AllPub    Corner      ...                 0        0    NaN
# 2         Lvl    AllPub    Inside      ...                 0        0    NaN
# 3         Lvl    AllPub    Inside      ...                 0        0    NaN
# 4         HLS    AllPub    Inside      ...               144        0    NaN
#
#    Fence MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# ...

# %% [markdown]
# Exploring the target variable "SalePrice"

# %%
train.SalePrice.describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %% [markdown]
# Printing the distribution of "SalesPrice" graph

# %%
sns.distplot(train['SalePrice'], color="r", kde=False)
plt.title("Distribution of Sale Price")
plt.ylabel("Number of Occurences")
plt.xlabel("Sale Price")
plt.show()

# %% [markdown]
# Showing all features in the train dataset illiustrated in graphs

# %%
def plot_feature(X):
    y = train.loc[X.index, 'SalePrice']
    plt.scatter(X, y)
    plt.xlabel('X')
    plt.ylabel('y')
    plt.title(X.name)
    
for feature in train.columns:
    X = train[feature].dropna()
    fig , (ax1, ax2) = plt.subplots(1,2, figsize=(10,5), sharex=True)
    plt.subplot(ax1)
    plot_feature(X)
    plt.subplot(ax2)
    if train[feature].dtype == np.dtype('object'):
        sns.countplot(X)
    else:
        sns.distplot(X)
        
plt.show()

# %% [markdown]
# ### Numerical features and correlation between them

# %% [markdown]
# Describing the statistical information about numerical features in the train dataset

# %%
train.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1201.000000    1460.000000  1460.000000  1460.000000
# mean     56.897260    70.049958   10516.828082     6.099315     5.575342
# std      42.300571    24.284752    9981.264932     1.382997     1.112799
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7553.500000     5.000000     5.000000
# 50%      50.000000    69.000000    9478.500000     6.000000     5.000000
# 75%      70.000000    80.000000   11601.500000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  \
# count  1460.000000   1460.000000  1452.000000  1460.000000  1460.000000
# mean   1971.267808   1984.865753   103.685262   443.639726    46.549315
# std      30.202904     20.645407   181.066207   456.098091   161.319273
# ...

# %% [markdown]
# Showing correlation matrix

# %%
# getting only numerical values
numeric_features = train.select_dtypes(include=[np.number])

# %%
# Compute the correlation matrix
corr = numeric_features.corr()

# %%
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

plt.show()

# %% [markdown]
# Correlaton between two features

# %%
correlations = train.corr()
attrs = correlations.iloc[:-1,:-1] # all except target

threshold = 0.5
important_corrs = (attrs[abs(attrs) > threshold][attrs != 1.0]) \
    .unstack().dropna().to_dict()

unique_important_corrs = pd.DataFrame(
    list(set([(tuple(sorted(key)), important_corrs[key]) \
    for key in important_corrs])), 
        columns=['Attribute Pair', 'Correlation'])

    # sorted by absolute value
unique_important_corrs = unique_important_corrs.ix[
    abs(unique_important_corrs['Correlation']).argsort()[::-1]]

unique_important_corrs
# Out:
#                   Attribute Pair  Correlation
# 16      (GarageArea, GarageCars)     0.882475
# 18      (GarageYrBlt, YearBuilt)     0.825667
# 14     (GrLivArea, TotRmsAbvGrd)     0.825489
# 21       (1stFlrSF, TotalBsmtSF)     0.819530
# 3          (2ndFlrSF, GrLivArea)     0.687501
# 7   (BedroomAbvGr, TotRmsAbvGrd)     0.676620
# 6     (BsmtFinSF1, BsmtFullBath)     0.649212
# 23   (GarageYrBlt, YearRemodAdd)     0.642277
# 2          (FullBath, GrLivArea)     0.630012
# 5       (2ndFlrSF, TotRmsAbvGrd)     0.616423
# 15          (2ndFlrSF, HalfBath)     0.609707
# 24     (GarageCars, OverallQual)     0.600671
# 9       (GrLivArea, OverallQual)     0.593007
# 25     (YearBuilt, YearRemodAdd)     0.592855
# 20     (GarageCars, GarageYrBlt)     0.588920
# 12      (OverallQual, YearBuilt)     0.572323
# 13         (1stFlrSF, GrLivArea)     0.566024
# 19     (GarageArea, GarageYrBlt)     0.564567
# 8      (GarageArea, OverallQual)     0.562022
# ...

# %% [markdown]
# Showing 5 most correlated features with "SalePrice" and the least 5 correlated features with the target value too

# %%
print (corr['SalePrice'].sort_values(ascending=False)[:5], '\n')
print (corr['SalePrice'].sort_values(ascending=False)[-5:])
# Out:
# SalePrice      1.000000
# OverallQual    0.790982
# GrLivArea      0.708624
# GarageCars     0.640409
# GarageArea     0.623431
# Name: SalePrice, dtype: float64
#
# YrSold          -0.028923
# OverallCond     -0.077856
# MSSubClass      -0.084284
# EnclosedPorch   -0.128578
# KitchenAbvGr    -0.135907
# Name: SalePrice, dtype: float64

# %% [markdown]
# ### Categorical Features

# %% [markdown]
# Describing the statistical information about categorical features in the dataset

# %%
categoricals = train.select_dtypes(exclude=[np.number])
categoricals.describe()
# Out:
#        MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# count      1460   1460    91     1460        1460      1460      1460
# unique        5      2     2        4           4         2         5
# top          RL   Pave  Grvl      Reg         Lvl    AllPub    Inside
# freq       1151   1454    50      925        1311      1459      1052
#
#        LandSlope Neighborhood Condition1      ...      GarageType  \
# count       1460         1460       1460      ...            1379
# unique         3           25          9      ...               6
# top          Gtl        NAmes       Norm      ...          Attchd
# freq        1382          225       1260      ...             870
#
#        GarageFinish GarageQual GarageCond PavedDrive PoolQC  Fence  \
# count          1379       1379       1379       1460      7    281
# unique            3          5          5          3      3      4
# top             Unf         TA         TA          Y     Gd  MnPrv
# ...

# %% [markdown]
# Showing how many categories have each categorical feature

# %%
for feature in categoricals:
    print ("Unique values of ",feature," : " , train[feature].nunique())
# Out:
# Unique values of  MSZoning  :  5
# Unique values of  Street  :  2
# Unique values of  Alley  :  2
# Unique values of  LotShape  :  4
# Unique values of  LandContour  :  4
# Unique values of  Utilities  :  2
# Unique values of  LotConfig  :  5
# Unique values of  LandSlope  :  3
# Unique values of  Neighborhood  :  25
# Unique values of  Condition1  :  9
# Unique values of  Condition2  :  8
# Unique values of  BldgType  :  5
# Unique values of  HouseStyle  :  8
# Unique values of  RoofStyle  :  6
# Unique values of  RoofMatl  :  8
# Unique values of  Exterior1st  :  15
# Unique values of  Exterior2nd  :  16
# Unique values of  MasVnrType  :  4
# Unique values of  ExterQual  :  4
# Unique values of  ExterCond  :  5
# Unique values of  Foundation  :  6
# Unique values of  BsmtQual  :  4
# Unique values of  BsmtCond  :  4
# Unique values of  BsmtExposure  :  4
# Unique values of  BsmtFinType1  :  6
# Unique values of  BsmtFinType2  :  6
# Unique values of  Heating  :  6
# ...

# %% [markdown]
# Showing all categorical features in the train dataset illiustrated in graphs

# %%
def boxplot(x, y, **kwargs):
    sns.boxplot(x=x, y=y)
f = pd.melt(train, id_vars=['SalePrice'], value_vars=categoricals)
g = sns.FacetGrid(f, col="variable",  col_wrap=2, sharex=False, sharey=False, size=5)
g = g.map(boxplot, "value", "SalePrice")
plt.show()

# %% [markdown]
# ### Features with missing values

# %% [markdown]
# Showing all features which have at least one missing value

# %%
nulls = pd.DataFrame(train.isnull().sum().sort_values(ascending=False)[:25])
nulls.columns = ['Null Count']
nulls.index.name = 'Feature'
nulls
# Out:
#               Null Count
# Feature
# PoolQC              1453
# MiscFeature         1406
# Alley               1369
# Fence               1179
# FireplaceQu          690
# LotFrontage          259
# GarageType            81
# GarageCond            81
# GarageFinish          81
# GarageQual            81
# GarageYrBlt           81
# BsmtFinType2          38
# BsmtExposure          38
# BsmtQual              37
# BsmtCond              37
# BsmtFinType1          37
# MasVnrArea             8
# MasVnrType             8
# Electrical             1
# RoofMatl               0
# Exterior1st            0
# RoofStyle              0
# ExterQual              0
# Exterior2nd            0
# YearBuilt              0

# %% [markdown]
# Plotting features with missing values

# %% [markdown]
# #### For Train set:

# %%
all_data_na = (train.isnull().sum() / len(train)) * 100
all_data_na = all_data_na.drop(all_data_na[all_data_na == 0].index).sort_values(ascending=False)[:30]

f, ax = plt.subplots(figsize=(15, 5))
plt.xticks(rotation='90')
sns.barplot(x=all_data_na.index, y=all_data_na)
plt.xlabel('Features', fontsize=15)
plt.ylabel('Percent of missing values', fontsize=15)
plt.title('Percent missing data by feature', fontsize=15)
plt.show()

# %% [markdown]
# #### For Test set:

# %%
all_data_na = (test.isnull().sum() / len(test)) * 100
all_data_na = all_data_na.drop(all_data_na[all_data_na == 0].index).sort_values(ascending=False)[:30]

f, ax = plt.subplots(figsize=(15, 5))
plt.xticks(rotation='90')
sns.barplot(x=all_data_na.index, y=all_data_na)
plt.xlabel('Features', fontsize=15)
plt.ylabel('Percent of missing values', fontsize=15)
plt.title('Percent missing data by feature', fontsize=15)
plt.show()
